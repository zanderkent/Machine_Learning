# %% [markdown]
# # This was a notebook that I created for an application.
# I cannot share the data, but I can share my process

# %% [markdown]
# # Import Libraries

# %%
#Import libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Read the data that I formatted from a previous notebook and split it into train and test

# %%
#Import data saved from data cleaning
X_train = pd.read_csv('training_features.csv', sep='\t')
columns = X_train.columns
Y_train = pd.read_csv('training_target.csv', sep='\t')
#Observe that is a class imbalance 80-20, should be fine. 
Y_train['y'].value_counts(normalize=True).reset_index()
# Out:
#    index       y
# 0      0  0.7978
# 1      1  0.2022

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X_train), np.array(Y_train))

# %% [markdown]
# # Changing Hyper Parameters
# You can change the learning rate, number of estimators, depth and such if you need to.
# Here is a good example of a gridsearch/randomsearch
# https://www.kaggle.com/tilii7/hyperparameter-grid-search-with-xgboost

# %%
model = XGBClassifier(
 learning_rate =0.01,
 n_estimators=4000,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 scale_pos_weight=1,
 n_jobs = -1,tree_method='gpu_hist',
 silent=False,verbose_eval=10,
 seed=27)

# %% [markdown]
# # Reviewing the training logs
# You can see that as the number of iterations goes through, the boosting is taking effect.
# Here is a good example of what boosting is: https://www.analyticsvidhya.com/blog/2015/11/quick-introduction-boosting-algorithms-machine-learning/
#
# Be careful not to overfit the training data, you can implement early stopping.

# %%
model.fit(X_train,y_train,eval_set=[(X_train, y_train), (X_test, y_test)],eval_metric='auc')
# Out:
# /home/zander/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/zander/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-auc:0.776607	validation_1-auc:0.776843
# [1]	validation_0-auc:0.83112	validation_1-auc:0.827569
# [2]	validation_0-auc:0.842366	validation_1-auc:0.837845
# [3]	validation_0-auc:0.843306	validation_1-auc:0.838323
# [4]	validation_0-auc:0.849169	validation_1-auc:0.8406
# [5]	validation_0-auc:0.869621	validation_1-auc:0.859007
# [6]	validation_0-auc:0.878989	validation_1-auc:0.867392
# [7]	validation_0-auc:0.879466	validation_1-auc:0.867476
# [8]	validation_0-auc:0.876641	validation_1-auc:0.864696
# [9]	validation_0-auc:0.885238	validation_1-auc:0.874567
# [10]	validation_0-auc:0.88746	validation_1-auc:0.876545
# [11]	validation_0-auc:0.885449	validation_1-auc:0.874205
# [12]	validation_0-auc:0.890342	validation_1-auc:0.878859
# [13]	validation_0-auc:0.889102	validation_1-auc:0.877797
# [14]	validation_0-auc:0.887155	validation_1-auc:0.87625
# [15]	validation_0-auc:0.888354	validation_1-auc:0.877093
# [16]	validation_0-auc:0.892103	validation_1-auc:0.880663
# [17]	validation_0-auc:0.892146	validation_1-auc:0.881008
# [18]	validation_0-auc:0.891925	validation_1-auc:0.881579
# [19]	validation_0-auc:0.895165	validation_1-auc:0.885894
# [20]	validation_0-auc:0.894677	validation_1-auc:0.885184
# [21]	validation_0-auc:0.893599	validation_1-auc:0.883915
# [22]	validation_0-auc:0.895184	validation_1-auc:0.885986
# [23]	validation_0-auc:0.894281	validation_1-auc:0.885218
# [24]	validation_0-auc:0.898343	validation_1-auc:0.888928
# [25]	validation_0-auc:0.897023	validation_1-auc:0.88765
# [26]	validation_0-auc:0.897431	validation_1-auc:0.888093
# [27]	validation_0-auc:0.896988	validation_1-auc:0.887844
# [28]	validation_0-auc:0.898006	validation_1-auc:0.888427
# [29]	validation_0-auc:0.897708	validation_1-auc:0.88813
# [30]	validation_0-auc:0.8995	validation_1-auc:0.890018
# [31]	validation_0-auc:0.898717	validation_1-auc:0.889222
# [32]	validation_0-auc:0.900469	validation_1-auc:0.89071
# [33]	validation_0-auc:0.900553	validation_1-auc:0.890596
# [34]	validation_0-auc:0.901763	validation_1-auc:0.891752
# [35]	validation_0-auc:0.900961	validation_1-auc:0.891159
# [36]	validation_0-auc:0.900538	validation_1-auc:0.890971
# [37]	validation_0-auc:0.901141	validation_1-auc:0.89171
# [38]	validation_0-auc:0.902588	validation_1-auc:0.893161
# [39]	validation_0-auc:0.903436	validation_1-auc:0.894121
# [40]	validation_0-auc:0.904329	validation_1-auc:0.895492
# [41]	validation_0-auc:0.904725	validation_1-auc:0.89586
# [42]	validation_0-auc:0.904992	validation_1-auc:0.895903
# [43]	validation_0-auc:0.905954	validation_1-auc:0.896833
# [44]	validation_0-auc:0.905219	validation_1-auc:0.896119
# [45]	validation_0-auc:0.906639	validation_1-auc:0.897465
# [46]	validation_0-auc:0.906388	validation_1-auc:0.89719
# [47]	validation_0-auc:0.906535	validation_1-auc:0.89741
# [48]	validation_0-auc:0.907694	validation_1-auc:0.898385
# [49]	validation_0-auc:0.907838	validation_1-auc:0.8986
# [50]	validation_0-auc:0.90912	validation_1-auc:0.89989
# [51]	validation_0-auc:0.909377	validation_1-auc:0.90029
# [52]	validation_0-auc:0.909885	validation_1-auc:0.900679
# [53]	validation_0-auc:0.909991	validation_1-auc:0.900605
# [54]	validation_0-auc:0.910929	validation_1-auc:0.901659
# [55]	validation_0-auc:0.911109	validation_1-auc:0.901837
# [56]	validation_0-auc:0.911437	validation_1-auc:0.90213
# [57]	validation_0-auc:0.911988	validation_1-auc:0.902583
# [58]	validation_0-auc:0.913142	validation_1-auc:0.903815
# [59]	validation_0-auc:0.913422	validation_1-auc:0.90422
# [60]	validation_0-auc:0.913812	validation_1-auc:0.904602
# [61]	validation_0-auc:0.914906	validation_1-auc:0.90561
# [62]	validation_0-auc:0.915061	validation_1-auc:0.905788
# [63]	validation_0-auc:0.915955	validation_1-auc:0.906876
# [64]	validation_0-auc:0.916283	validation_1-auc:0.907127
# [65]	validation_0-auc:0.916515	validation_1-auc:0.907299
# [66]	validation_0-auc:0.916992	validation_1-auc:0.907734
# [67]	validation_0-auc:0.916995	validation_1-auc:0.907684
# [68]	validation_0-auc:0.917545	validation_1-auc:0.90805
# [69]	validation_0-auc:0.917967	validation_1-auc:0.908274
# [70]	validation_0-auc:0.9182	validation_1-auc:0.908569
# [71]	validation_0-auc:0.918665	validation_1-auc:0.90885
# [72]	validation_0-auc:0.919003	validation_1-auc:0.909104
# [73]	validation_0-auc:0.919324	validation_1-auc:0.90918
# [74]	validation_0-auc:0.919894	validation_1-auc:0.909639
# [75]	validation_0-auc:0.91975	validation_1-auc:0.909492
# [76]	validation_0-auc:0.920147	validation_1-auc:0.909782
# [77]	validation_0-auc:0.920743	validation_1-auc:0.910427
# [78]	validation_0-auc:0.920868	validation_1-auc:0.910668
# [79]	validation_0-auc:0.92113	validation_1-auc:0.910801
# [80]	validation_0-auc:0.921441	validation_1-auc:0.911056
# [81]	validation_0-auc:0.922186	validation_1-auc:0.911662
# [82]	validation_0-auc:0.921987	validation_1-auc:0.911614
# [83]	validation_0-auc:0.922777	validation_1-auc:0.912483
# [84]	validation_0-auc:0.923143	validation_1-auc:0.912771
# [85]	validation_0-auc:0.923308	validation_1-auc:0.913042
# [86]	validation_0-auc:0.92335	validation_1-auc:0.913069
# [87]	validation_0-auc:0.923886	validation_1-auc:0.913581
# [88]	validation_0-auc:0.924691	validation_1-auc:0.91427
# [89]	validation_0-auc:0.925149	validation_1-auc:0.914556
# [90]	validation_0-auc:0.925547	validation_1-auc:0.91488
# [91]	validation_0-auc:0.925824	validation_1-auc:0.915096
# [92]	validation_0-auc:0.926142	validation_1-auc:0.915414
# [93]	validation_0-auc:0.92694	validation_1-auc:0.916066
# [94]	validation_0-auc:0.927416	validation_1-auc:0.916515
# [95]	validation_0-auc:0.927762	validation_1-auc:0.916908
# [96]	validation_0-auc:0.928466	validation_1-auc:0.91783
# [97]	validation_0-auc:0.928787	validation_1-auc:0.918183
# [98]	validation_0-auc:0.929035	validation_1-auc:0.91841
# [99]	validation_0-auc:0.929996	validation_1-auc:0.919348
# [100]	validation_0-auc:0.930416	validation_1-auc:0.919733
# [101]	validation_0-auc:0.930638	validation_1-auc:0.919933
# [102]	validation_0-auc:0.930883	validation_1-auc:0.920098
# [103]	validation_0-auc:0.931106	validation_1-auc:0.920373
# [104]	validation_0-auc:0.931554	validation_1-auc:0.920786
# [105]	validation_0-auc:0.932102	validation_1-auc:0.921164
# [106]	validation_0-auc:0.932767	validation_1-auc:0.921916
# [107]	validation_0-auc:0.932833	validation_1-auc:0.921867
# [108]	validation_0-auc:0.933293	validation_1-auc:0.922379
# [109]	validation_0-auc:0.933292	validation_1-auc:0.922346
# [110]	validation_0-auc:0.933781	validation_1-auc:0.92273
# [111]	validation_0-auc:0.934428	validation_1-auc:0.92333
# [112]	validation_0-auc:0.934847	validation_1-auc:0.923693
# [113]	validation_0-auc:0.934623	validation_1-auc:0.923426
# [114]	validation_0-auc:0.934875	validation_1-auc:0.923642
# [115]	validation_0-auc:0.935537	validation_1-auc:0.924282
# [116]	validation_0-auc:0.935786	validation_1-auc:0.92443
# [117]	validation_0-auc:0.936154	validation_1-auc:0.924803
# [118]	validation_0-auc:0.936483	validation_1-auc:0.92518
# [119]	validation_0-auc:0.936477	validation_1-auc:0.925115
# [120]	validation_0-auc:0.936672	validation_1-auc:0.925193
# [121]	validation_0-auc:0.937314	validation_1-auc:0.925752
# [122]	validation_0-auc:0.937572	validation_1-auc:0.926002
# [123]	validation_0-auc:0.938043	validation_1-auc:0.926427
# [124]	validation_0-auc:0.938277	validation_1-auc:0.92662
# [125]	validation_0-auc:0.938929	validation_1-auc:0.927411
# [126]	validation_0-auc:0.939328	validation_1-auc:0.927678
# [127]	validation_0-auc:0.939684	validation_1-auc:0.928014
# [128]	validation_0-auc:0.939865	validation_1-auc:0.928097
# [129]	validation_0-auc:0.940144	validation_1-auc:0.92823
# [130]	validation_0-auc:0.940239	validation_1-auc:0.928176
# [131]	validation_0-auc:0.940576	validation_1-auc:0.928665
# [132]	validation_0-auc:0.941109	validation_1-auc:0.929215
# [133]	validation_0-auc:0.941491	validation_1-auc:0.929647
# [134]	validation_0-auc:0.941991	validation_1-auc:0.930085
# [135]	validation_0-auc:0.942384	validation_1-auc:0.930522
# [136]	validation_0-auc:0.942592	validation_1-auc:0.930672
# [137]	validation_0-auc:0.943014	validation_1-auc:0.93114
# [138]	validation_0-auc:0.943256	validation_1-auc:0.931357
# [139]	validation_0-auc:0.943381	validation_1-auc:0.931458
# [140]	validation_0-auc:0.943737	validation_1-auc:0.931897
# [141]	validation_0-auc:0.943904	validation_1-auc:0.932058
# [142]	validation_0-auc:0.944138	validation_1-auc:0.932154
# [143]	validation_0-auc:0.944208	validation_1-auc:0.932203
# [144]	validation_0-auc:0.944672	validation_1-auc:0.932716
# [145]	validation_0-auc:0.94507	validation_1-auc:0.933155
# [146]	validation_0-auc:0.945231	validation_1-auc:0.933359
# [147]	validation_0-auc:0.945397	validation_1-auc:0.93356
# [148]	validation_0-auc:0.945612	validation_1-auc:0.933778
# [149]	validation_0-auc:0.946058	validation_1-auc:0.934237
# [150]	validation_0-auc:0.946467	validation_1-auc:0.934668
# [151]	validation_0-auc:0.946812	validation_1-auc:0.93503
# [152]	validation_0-auc:0.947069	validation_1-auc:0.935288
# [153]	validation_0-auc:0.947129	validation_1-auc:0.935282
# [154]	validation_0-auc:0.947266	validation_1-auc:0.935381
# [155]	validation_0-auc:0.947655	validation_1-auc:0.935813
# [156]	validation_0-auc:0.947868	validation_1-auc:0.936008
# [157]	validation_0-auc:0.948075	validation_1-auc:0.936096
# [158]	validation_0-auc:0.948217	validation_1-auc:0.936221
# [159]	validation_0-auc:0.948543	validation_1-auc:0.936474
# [160]	validation_0-auc:0.948855	validation_1-auc:0.936808
# [161]	validation_0-auc:0.948933	validation_1-auc:0.936901
# [162]	validation_0-auc:0.949267	validation_1-auc:0.937255
# [163]	validation_0-auc:0.949608	validation_1-auc:0.937739
# [164]	validation_0-auc:0.949679	validation_1-auc:0.937811
# [165]	validation_0-auc:0.94991	validation_1-auc:0.937988
# [166]	validation_0-auc:0.950361	validation_1-auc:0.938446
# [167]	validation_0-auc:0.950717	validation_1-auc:0.93881
# [168]	validation_0-auc:0.950883	validation_1-auc:0.938948
# [169]	validation_0-auc:0.951186	validation_1-auc:0.93929
# [170]	validation_0-auc:0.951455	validation_1-auc:0.939466
# [171]	validation_0-auc:0.951688	validation_1-auc:0.939708
# [172]	validation_0-auc:0.951983	validation_1-auc:0.940068
# [173]	validation_0-auc:0.952057	validation_1-auc:0.940117
# [174]	validation_0-auc:0.952222	validation_1-auc:0.940281
# [175]	validation_0-auc:0.952285	validation_1-auc:0.94042
# [176]	validation_0-auc:0.952396	validation_1-auc:0.940475
# [177]	validation_0-auc:0.95281	validation_1-auc:0.940867
# [178]	validation_0-auc:0.953249	validation_1-auc:0.941198
# [179]	validation_0-auc:0.9535	validation_1-auc:0.941574
# [180]	validation_0-auc:0.953796	validation_1-auc:0.941803
# [181]	validation_0-auc:0.953824	validation_1-auc:0.941842
# [182]	validation_0-auc:0.954084	validation_1-auc:0.942184
# [183]	validation_0-auc:0.954226	validation_1-auc:0.942346
# [184]	validation_0-auc:0.954401	validation_1-auc:0.942497
# [185]	validation_0-auc:0.954621	validation_1-auc:0.942723
# [186]	validation_0-auc:0.954696	validation_1-auc:0.942786
# [187]	validation_0-auc:0.95477	validation_1-auc:0.942866
# [188]	validation_0-auc:0.954917	validation_1-auc:0.943024
# [189]	validation_0-auc:0.955036	validation_1-auc:0.943136
# [190]	validation_0-auc:0.955117	validation_1-auc:0.943239
# [191]	validation_0-auc:0.955324	validation_1-auc:0.943446
# [192]	validation_0-auc:0.955459	validation_1-auc:0.943526
# [193]	validation_0-auc:0.95577	validation_1-auc:0.943813
# [194]	validation_0-auc:0.955983	validation_1-auc:0.944012
# [195]	validation_0-auc:0.956324	validation_1-auc:0.944357
# [196]	validation_0-auc:0.956367	validation_1-auc:0.944432
# [197]	validation_0-auc:0.956524	validation_1-auc:0.944594
# [198]	validation_0-auc:0.956762	validation_1-auc:0.945001
# [199]	validation_0-auc:0.95701	validation_1-auc:0.945229
# [200]	validation_0-auc:0.957138	validation_1-auc:0.945336
# [201]	validation_0-auc:0.957344	validation_1-auc:0.945516
# [202]	validation_0-auc:0.957604	validation_1-auc:0.945762
# [203]	validation_0-auc:0.957816	validation_1-auc:0.945925
# [204]	validation_0-auc:0.958118	validation_1-auc:0.946278
# [205]	validation_0-auc:0.958475	validation_1-auc:0.946631
# [206]	validation_0-auc:0.958602	validation_1-auc:0.94675
# [207]	validation_0-auc:0.958807	validation_1-auc:0.946928
# [208]	validation_0-auc:0.95902	validation_1-auc:0.947067
# [209]	validation_0-auc:0.959131	validation_1-auc:0.947089
# [210]	validation_0-auc:0.95929	validation_1-auc:0.947145
# [211]	validation_0-auc:0.959381	validation_1-auc:0.94733
# [212]	validation_0-auc:0.959643	validation_1-auc:0.947543
# [213]	validation_0-auc:0.959893	validation_1-auc:0.947798
# [214]	validation_0-auc:0.960025	validation_1-auc:0.94794
# [215]	validation_0-auc:0.960136	validation_1-auc:0.94805
# [216]	validation_0-auc:0.960237	validation_1-auc:0.948074
# [217]	validation_0-auc:0.960353	validation_1-auc:0.948086
# [218]	validation_0-auc:0.960499	validation_1-auc:0.948232
# [219]	validation_0-auc:0.960727	validation_1-auc:0.948481
# [220]	validation_0-auc:0.960859	validation_1-auc:0.948578
# [221]	validation_0-auc:0.961023	validation_1-auc:0.94876
# [222]	validation_0-auc:0.961152	validation_1-auc:0.948959
# [223]	validation_0-auc:0.961351	validation_1-auc:0.949161
# [224]	validation_0-auc:0.961406	validation_1-auc:0.949212
# [225]	validation_0-auc:0.961457	validation_1-auc:0.949304
# [226]	validation_0-auc:0.961565	validation_1-auc:0.949383
# [227]	validation_0-auc:0.961754	validation_1-auc:0.94955
# [228]	validation_0-auc:0.961963	validation_1-auc:0.94976
# [229]	validation_0-auc:0.962121	validation_1-auc:0.949937
# [230]	validation_0-auc:0.962341	validation_1-auc:0.950151
# [231]	validation_0-auc:0.9625	validation_1-auc:0.950336
# [232]	validation_0-auc:0.962723	validation_1-auc:0.950547
# [233]	validation_0-auc:0.962888	validation_1-auc:0.950709
# [234]	validation_0-auc:0.963017	validation_1-auc:0.950907
# [235]	validation_0-auc:0.963051	validation_1-auc:0.950934
# [236]	validation_0-auc:0.963191	validation_1-auc:0.951047
# [237]	validation_0-auc:0.963296	validation_1-auc:0.951176
# [238]	validation_0-auc:0.963452	validation_1-auc:0.951348
# [239]	validation_0-auc:0.963632	validation_1-auc:0.951578
# [240]	validation_0-auc:0.963853	validation_1-auc:0.951831
# [241]	validation_0-auc:0.963892	validation_1-auc:0.951899
# [242]	validation_0-auc:0.964032	validation_1-auc:0.952068
# [243]	validation_0-auc:0.964131	validation_1-auc:0.952144
# [244]	validation_0-auc:0.964194	validation_1-auc:0.952165
# [245]	validation_0-auc:0.964251	validation_1-auc:0.952238
# [246]	validation_0-auc:0.964433	validation_1-auc:0.95242
# [247]	validation_0-auc:0.964591	validation_1-auc:0.952567
# [248]	validation_0-auc:0.964687	validation_1-auc:0.95265
# [249]	validation_0-auc:0.964825	validation_1-auc:0.952823
# [250]	validation_0-auc:0.965009	validation_1-auc:0.953
# [251]	validation_0-auc:0.965102	validation_1-auc:0.953115
# [252]	validation_0-auc:0.965282	validation_1-auc:0.953283
# [253]	validation_0-auc:0.965408	validation_1-auc:0.953398
# [254]	validation_0-auc:0.965491	validation_1-auc:0.953494
# [255]	validation_0-auc:0.965539	validation_1-auc:0.953538
# [256]	validation_0-auc:0.965615	validation_1-auc:0.95358
# [257]	validation_0-auc:0.965781	validation_1-auc:0.9538
# [258]	validation_0-auc:0.965926	validation_1-auc:0.953938
# [259]	validation_0-auc:0.96601	validation_1-auc:0.954054
# [260]	validation_0-auc:0.966141	validation_1-auc:0.954193
# [261]	validation_0-auc:0.966298	validation_1-auc:0.954431
# [262]	validation_0-auc:0.966451	validation_1-auc:0.954591
# [263]	validation_0-auc:0.966576	validation_1-auc:0.954695
# [264]	validation_0-auc:0.966696	validation_1-auc:0.954855
# [265]	validation_0-auc:0.966759	validation_1-auc:0.954896
# [266]	validation_0-auc:0.966806	validation_1-auc:0.95493
# [267]	validation_0-auc:0.966838	validation_1-auc:0.95503
# [268]	validation_0-auc:0.966977	validation_1-auc:0.955167
# [269]	validation_0-auc:0.967092	validation_1-auc:0.955243
# [270]	validation_0-auc:0.96731	validation_1-auc:0.955463
# [271]	validation_0-auc:0.967381	validation_1-auc:0.955547
# [272]	validation_0-auc:0.967449	validation_1-auc:0.955618
# [273]	validation_0-auc:0.96756	validation_1-auc:0.955741
# [274]	validation_0-auc:0.967636	validation_1-auc:0.955839
# [275]	validation_0-auc:0.967713	validation_1-auc:0.955958
# [276]	validation_0-auc:0.967843	validation_1-auc:0.956129
# [277]	validation_0-auc:0.96789	validation_1-auc:0.956152
# [278]	validation_0-auc:0.967977	validation_1-auc:0.956227
# [279]	validation_0-auc:0.968043	validation_1-auc:0.95632
# [280]	validation_0-auc:0.968151	validation_1-auc:0.956472
# [281]	validation_0-auc:0.968151	validation_1-auc:0.956421
# [282]	validation_0-auc:0.968215	validation_1-auc:0.956453
# [283]	validation_0-auc:0.96835	validation_1-auc:0.956563
# [284]	validation_0-auc:0.968412	validation_1-auc:0.956645
# [285]	validation_0-auc:0.968524	validation_1-auc:0.956789
# [286]	validation_0-auc:0.968608	validation_1-auc:0.956875
# [287]	validation_0-auc:0.968768	validation_1-auc:0.957072
# [288]	validation_0-auc:0.968833	validation_1-auc:0.957132
# [289]	validation_0-auc:0.968909	validation_1-auc:0.957209
# [290]	validation_0-auc:0.968982	validation_1-auc:0.957277
# [291]	validation_0-auc:0.969085	validation_1-auc:0.957398
# [292]	validation_0-auc:0.969147	validation_1-auc:0.957479
# [293]	validation_0-auc:0.969166	validation_1-auc:0.957476
# [294]	validation_0-auc:0.969265	validation_1-auc:0.957592
# [295]	validation_0-auc:0.96937	validation_1-auc:0.957663
# [296]	validation_0-auc:0.96945	validation_1-auc:0.957741
# [297]	validation_0-auc:0.969496	validation_1-auc:0.957781
# [298]	validation_0-auc:0.96965	validation_1-auc:0.95793
# [299]	validation_0-auc:0.969758	validation_1-auc:0.958025
# [300]	validation_0-auc:0.969892	validation_1-auc:0.958182
# [301]	validation_0-auc:0.970007	validation_1-auc:0.958273
# [302]	validation_0-auc:0.970079	validation_1-auc:0.958363
# [303]	validation_0-auc:0.970136	validation_1-auc:0.958414
# [304]	validation_0-auc:0.9703	validation_1-auc:0.958573
# [305]	validation_0-auc:0.970436	validation_1-auc:0.958701
# [306]	validation_0-auc:0.97054	validation_1-auc:0.958844
# [307]	validation_0-auc:0.970602	validation_1-auc:0.958872
# [308]	validation_0-auc:0.970679	validation_1-auc:0.958896
# [309]	validation_0-auc:0.970783	validation_1-auc:0.958989
# [310]	validation_0-auc:0.970871	validation_1-auc:0.95907
# [311]	validation_0-auc:0.970918	validation_1-auc:0.959123
# [312]	validation_0-auc:0.971064	validation_1-auc:0.959267
# [313]	validation_0-auc:0.971143	validation_1-auc:0.959367
# [314]	validation_0-auc:0.971192	validation_1-auc:0.959405
# [315]	validation_0-auc:0.971295	validation_1-auc:0.959529
# [316]	validation_0-auc:0.971434	validation_1-auc:0.959707
# [317]	validation_0-auc:0.971595	validation_1-auc:0.95986
# [318]	validation_0-auc:0.971721	validation_1-auc:0.960005
# [319]	validation_0-auc:0.971833	validation_1-auc:0.960131
# [320]	validation_0-auc:0.97192	validation_1-auc:0.960239
# [321]	validation_0-auc:0.971971	validation_1-auc:0.960297
# [322]	validation_0-auc:0.97201	validation_1-auc:0.960315
# [323]	validation_0-auc:0.972121	validation_1-auc:0.960484
# [324]	validation_0-auc:0.972179	validation_1-auc:0.960558
# [325]	validation_0-auc:0.972281	validation_1-auc:0.960668
# [326]	validation_0-auc:0.97238	validation_1-auc:0.960785
# [327]	validation_0-auc:0.972424	validation_1-auc:0.960822
# [328]	validation_0-auc:0.972488	validation_1-auc:0.960863
# [329]	validation_0-auc:0.972556	validation_1-auc:0.960949
# [330]	validation_0-auc:0.972604	validation_1-auc:0.960981
# [331]	validation_0-auc:0.972726	validation_1-auc:0.961105
# [332]	validation_0-auc:0.972836	validation_1-auc:0.961227
# [333]	validation_0-auc:0.973005	validation_1-auc:0.961403
# [334]	validation_0-auc:0.973029	validation_1-auc:0.961396
# [335]	validation_0-auc:0.973152	validation_1-auc:0.961499
# [336]	validation_0-auc:0.973287	validation_1-auc:0.96164
# [337]	validation_0-auc:0.973373	validation_1-auc:0.961756
# [338]	validation_0-auc:0.973408	validation_1-auc:0.961776
# [339]	validation_0-auc:0.973461	validation_1-auc:0.961846
# [340]	validation_0-auc:0.973534	validation_1-auc:0.961894
# [341]	validation_0-auc:0.973598	validation_1-auc:0.961962
# [342]	validation_0-auc:0.973746	validation_1-auc:0.962107
# [343]	validation_0-auc:0.97384	validation_1-auc:0.962197
# [344]	validation_0-auc:0.973952	validation_1-auc:0.962324
# [345]	validation_0-auc:0.974018	validation_1-auc:0.962392
# [346]	validation_0-auc:0.974085	validation_1-auc:0.962504
# [347]	validation_0-auc:0.97415	validation_1-auc:0.962583
# [348]	validation_0-auc:0.974199	validation_1-auc:0.96263
# [349]	validation_0-auc:0.974299	validation_1-auc:0.962699
# [350]	validation_0-auc:0.97446	validation_1-auc:0.962852
# [351]	validation_0-auc:0.974582	validation_1-auc:0.96298
# [352]	validation_0-auc:0.974717	validation_1-auc:0.963137
# [353]	validation_0-auc:0.974826	validation_1-auc:0.963232
# [354]	validation_0-auc:0.974859	validation_1-auc:0.96328
# [355]	validation_0-auc:0.974919	validation_1-auc:0.963366
# [356]	validation_0-auc:0.974973	validation_1-auc:0.963452
# [357]	validation_0-auc:0.975059	validation_1-auc:0.963536
# [358]	validation_0-auc:0.975163	validation_1-auc:0.963642
# [359]	validation_0-auc:0.975264	validation_1-auc:0.963724
# [360]	validation_0-auc:0.975334	validation_1-auc:0.963779
# [361]	validation_0-auc:0.975361	validation_1-auc:0.963836
# [362]	validation_0-auc:0.975415	validation_1-auc:0.963922
# [363]	validation_0-auc:0.975464	validation_1-auc:0.963968
# [364]	validation_0-auc:0.975502	validation_1-auc:0.963978
# [365]	validation_0-auc:0.975565	validation_1-auc:0.964043
# [366]	validation_0-auc:0.975608	validation_1-auc:0.96411
# [367]	validation_0-auc:0.975665	validation_1-auc:0.964145
# [368]	validation_0-auc:0.975706	validation_1-auc:0.964202
# [369]	validation_0-auc:0.975782	validation_1-auc:0.964258
# [370]	validation_0-auc:0.975874	validation_1-auc:0.964356
# [371]	validation_0-auc:0.975967	validation_1-auc:0.964427
# [372]	validation_0-auc:0.976056	validation_1-auc:0.964529
# [373]	validation_0-auc:0.976137	validation_1-auc:0.964614
# [374]	validation_0-auc:0.976194	validation_1-auc:0.964693
# [375]	validation_0-auc:0.976279	validation_1-auc:0.964785
# [376]	validation_0-auc:0.976295	validation_1-auc:0.964788
# [377]	validation_0-auc:0.976359	validation_1-auc:0.964862
# [378]	validation_0-auc:0.976455	validation_1-auc:0.964961
# [379]	validation_0-auc:0.976538	validation_1-auc:0.965044
# [380]	validation_0-auc:0.976592	validation_1-auc:0.965071
# [381]	validation_0-auc:0.976649	validation_1-auc:0.965125
# [382]	validation_0-auc:0.976695	validation_1-auc:0.965146
# [383]	validation_0-auc:0.976749	validation_1-auc:0.965241
# [384]	validation_0-auc:0.976783	validation_1-auc:0.965298
# [385]	validation_0-auc:0.97684	validation_1-auc:0.965373
# [386]	validation_0-auc:0.976879	validation_1-auc:0.965431
# [387]	validation_0-auc:0.976897	validation_1-auc:0.965445
# [388]	validation_0-auc:0.976934	validation_1-auc:0.965508
# [389]	validation_0-auc:0.977004	validation_1-auc:0.965609
# [390]	validation_0-auc:0.977081	validation_1-auc:0.965714
# [391]	validation_0-auc:0.977109	validation_1-auc:0.965736
# [392]	validation_0-auc:0.977148	validation_1-auc:0.965774
# [393]	validation_0-auc:0.977204	validation_1-auc:0.965808
# [394]	validation_0-auc:0.977223	validation_1-auc:0.965804
# [395]	validation_0-auc:0.977294	validation_1-auc:0.965861
# [396]	validation_0-auc:0.977396	validation_1-auc:0.965942
# [397]	validation_0-auc:0.977456	validation_1-auc:0.966017
# [398]	validation_0-auc:0.97752	validation_1-auc:0.96607
# [399]	validation_0-auc:0.9776	validation_1-auc:0.966175
# [400]	validation_0-auc:0.977676	validation_1-auc:0.966249
# [401]	validation_0-auc:0.977758	validation_1-auc:0.966309
# [402]	validation_0-auc:0.977793	validation_1-auc:0.966346
# [403]	validation_0-auc:0.977894	validation_1-auc:0.966434
# [404]	validation_0-auc:0.977967	validation_1-auc:0.966505
# [405]	validation_0-auc:0.978037	validation_1-auc:0.966572
# [406]	validation_0-auc:0.978118	validation_1-auc:0.966701
# [407]	validation_0-auc:0.978177	validation_1-auc:0.96675
# [408]	validation_0-auc:0.978254	validation_1-auc:0.966873
# [409]	validation_0-auc:0.978333	validation_1-auc:0.966985
# [410]	validation_0-auc:0.978391	validation_1-auc:0.967032
# [411]	validation_0-auc:0.978435	validation_1-auc:0.967076
# [412]	validation_0-auc:0.978517	validation_1-auc:0.967164
# [413]	validation_0-auc:0.978573	validation_1-auc:0.967212
# [414]	validation_0-auc:0.978627	validation_1-auc:0.967275
# [415]	validation_0-auc:0.978685	validation_1-auc:0.967344
# [416]	validation_0-auc:0.978756	validation_1-auc:0.967424
# [417]	validation_0-auc:0.978821	validation_1-auc:0.967482
# [418]	validation_0-auc:0.978891	validation_1-auc:0.967588
# [419]	validation_0-auc:0.978948	validation_1-auc:0.967666
# [420]	validation_0-auc:0.97901	validation_1-auc:0.967746
# [421]	validation_0-auc:0.979069	validation_1-auc:0.967817
# [422]	validation_0-auc:0.979126	validation_1-auc:0.967859
# [423]	validation_0-auc:0.97916	validation_1-auc:0.967916
# [424]	validation_0-auc:0.979177	validation_1-auc:0.96796
# [425]	validation_0-auc:0.979241	validation_1-auc:0.968042
# [426]	validation_0-auc:0.979316	validation_1-auc:0.968124
# [427]	validation_0-auc:0.97937	validation_1-auc:0.968189
# [428]	validation_0-auc:0.97941	validation_1-auc:0.968207
# [429]	validation_0-auc:0.979461	validation_1-auc:0.96824
# [430]	validation_0-auc:0.979524	validation_1-auc:0.968338
# [431]	validation_0-auc:0.979582	validation_1-auc:0.96838
# [432]	validation_0-auc:0.979654	validation_1-auc:0.968479
# [433]	validation_0-auc:0.979722	validation_1-auc:0.968551
# [434]	validation_0-auc:0.979786	validation_1-auc:0.968636
# [435]	validation_0-auc:0.979849	validation_1-auc:0.968695
# [436]	validation_0-auc:0.979881	validation_1-auc:0.968721
# [437]	validation_0-auc:0.979918	validation_1-auc:0.968758
# [438]	validation_0-auc:0.979933	validation_1-auc:0.968774
# [439]	validation_0-auc:0.979976	validation_1-auc:0.96884
# [440]	validation_0-auc:0.980004	validation_1-auc:0.968849
# [441]	validation_0-auc:0.980051	validation_1-auc:0.96886
# [442]	validation_0-auc:0.980123	validation_1-auc:0.968943
# [443]	validation_0-auc:0.980138	validation_1-auc:0.968961
# [444]	validation_0-auc:0.980169	validation_1-auc:0.968979
# [445]	validation_0-auc:0.980197	validation_1-auc:0.969016
# [446]	validation_0-auc:0.980256	validation_1-auc:0.969076
# [447]	validation_0-auc:0.980296	validation_1-auc:0.969114
# [448]	validation_0-auc:0.980363	validation_1-auc:0.969195
# [449]	validation_0-auc:0.980426	validation_1-auc:0.969241
# [450]	validation_0-auc:0.980514	validation_1-auc:0.969349
# [451]	validation_0-auc:0.980548	validation_1-auc:0.969368
# [452]	validation_0-auc:0.980582	validation_1-auc:0.969391
# [453]	validation_0-auc:0.980598	validation_1-auc:0.96941
# [454]	validation_0-auc:0.980643	validation_1-auc:0.969444
# [455]	validation_0-auc:0.980663	validation_1-auc:0.969474
# [456]	validation_0-auc:0.980707	validation_1-auc:0.969515
# [457]	validation_0-auc:0.980775	validation_1-auc:0.969616
# [458]	validation_0-auc:0.980858	validation_1-auc:0.969698
# [459]	validation_0-auc:0.980892	validation_1-auc:0.969746
# [460]	validation_0-auc:0.980969	validation_1-auc:0.969831
# [461]	validation_0-auc:0.981016	validation_1-auc:0.969881
# [462]	validation_0-auc:0.98107	validation_1-auc:0.969953
# [463]	validation_0-auc:0.981117	validation_1-auc:0.97
# [464]	validation_0-auc:0.981167	validation_1-auc:0.970069
# [465]	validation_0-auc:0.981203	validation_1-auc:0.9701
# [466]	validation_0-auc:0.981228	validation_1-auc:0.970104
# [467]	validation_0-auc:0.981279	validation_1-auc:0.970165
# [468]	validation_0-auc:0.9813	validation_1-auc:0.970174
# [469]	validation_0-auc:0.981355	validation_1-auc:0.970232
# [470]	validation_0-auc:0.981405	validation_1-auc:0.970256
# [471]	validation_0-auc:0.981439	validation_1-auc:0.970266
# [472]	validation_0-auc:0.98146	validation_1-auc:0.970291
# [473]	validation_0-auc:0.981524	validation_1-auc:0.970363
# [474]	validation_0-auc:0.981574	validation_1-auc:0.970385
# [475]	validation_0-auc:0.98161	validation_1-auc:0.970414
# [476]	validation_0-auc:0.981674	validation_1-auc:0.970461
# [477]	validation_0-auc:0.981724	validation_1-auc:0.970538
# [478]	validation_0-auc:0.98176	validation_1-auc:0.970565
# [479]	validation_0-auc:0.981833	validation_1-auc:0.970625
# [480]	validation_0-auc:0.981891	validation_1-auc:0.97069
# [481]	validation_0-auc:0.981929	validation_1-auc:0.970725
# [482]	validation_0-auc:0.981973	validation_1-auc:0.970774
# [483]	validation_0-auc:0.981985	validation_1-auc:0.970779
# [484]	validation_0-auc:0.982023	validation_1-auc:0.970809
# [485]	validation_0-auc:0.98208	validation_1-auc:0.970863
# [486]	validation_0-auc:0.982112	validation_1-auc:0.9709
# [487]	validation_0-auc:0.982158	validation_1-auc:0.970955
# [488]	validation_0-auc:0.982187	validation_1-auc:0.971
# [489]	validation_0-auc:0.98222	validation_1-auc:0.971051
# [490]	validation_0-auc:0.982277	validation_1-auc:0.971123
# [491]	validation_0-auc:0.982316	validation_1-auc:0.97115
# [492]	validation_0-auc:0.982347	validation_1-auc:0.971181
# [493]	validation_0-auc:0.982358	validation_1-auc:0.971198
# [494]	validation_0-auc:0.98237	validation_1-auc:0.971221
# [495]	validation_0-auc:0.9824	validation_1-auc:0.971262
# [496]	validation_0-auc:0.98243	validation_1-auc:0.971259
# [497]	validation_0-auc:0.982465	validation_1-auc:0.971288
# [498]	validation_0-auc:0.982495	validation_1-auc:0.971326
# [499]	validation_0-auc:0.982543	validation_1-auc:0.971369
# [500]	validation_0-auc:0.982578	validation_1-auc:0.971391
# [501]	validation_0-auc:0.982587	validation_1-auc:0.971413
# [502]	validation_0-auc:0.982616	validation_1-auc:0.97146
# [503]	validation_0-auc:0.982644	validation_1-auc:0.971478
# [504]	validation_0-auc:0.982688	validation_1-auc:0.971519
# [505]	validation_0-auc:0.982726	validation_1-auc:0.971582
# [506]	validation_0-auc:0.982728	validation_1-auc:0.971587
# [507]	validation_0-auc:0.98276	validation_1-auc:0.971609
# [508]	validation_0-auc:0.982805	validation_1-auc:0.971652
# [509]	validation_0-auc:0.982831	validation_1-auc:0.971679
# [510]	validation_0-auc:0.982862	validation_1-auc:0.971712
# [511]	validation_0-auc:0.982904	validation_1-auc:0.971761
# [512]	validation_0-auc:0.982961	validation_1-auc:0.971816
# [513]	validation_0-auc:0.982977	validation_1-auc:0.971825
# [514]	validation_0-auc:0.98301	validation_1-auc:0.971839
# [515]	validation_0-auc:0.983053	validation_1-auc:0.971878
# [516]	validation_0-auc:0.983091	validation_1-auc:0.971919
# [517]	validation_0-auc:0.983131	validation_1-auc:0.971965
# [518]	validation_0-auc:0.983172	validation_1-auc:0.97203
# [519]	validation_0-auc:0.983215	validation_1-auc:0.97207
# [520]	validation_0-auc:0.983255	validation_1-auc:0.972116
# [521]	validation_0-auc:0.983303	validation_1-auc:0.972149
# [522]	validation_0-auc:0.983351	validation_1-auc:0.972202
# [523]	validation_0-auc:0.983397	validation_1-auc:0.972246
# [524]	validation_0-auc:0.983424	validation_1-auc:0.972271
# [525]	validation_0-auc:0.983442	validation_1-auc:0.972291
# [526]	validation_0-auc:0.983489	validation_1-auc:0.972319
# [527]	validation_0-auc:0.983571	validation_1-auc:0.972405
# [528]	validation_0-auc:0.983599	validation_1-auc:0.972416
# [529]	validation_0-auc:0.983631	validation_1-auc:0.972462
# [530]	validation_0-auc:0.98368	validation_1-auc:0.972495
# [531]	validation_0-auc:0.983681	validation_1-auc:0.972517
# [532]	validation_0-auc:0.983715	validation_1-auc:0.972549
# [533]	validation_0-auc:0.983753	validation_1-auc:0.972597
# [534]	validation_0-auc:0.983797	validation_1-auc:0.972661
# [535]	validation_0-auc:0.98382	validation_1-auc:0.97268
# [536]	validation_0-auc:0.983858	validation_1-auc:0.97271
# [537]	validation_0-auc:0.983894	validation_1-auc:0.972747
# [538]	validation_0-auc:0.983948	validation_1-auc:0.972789
# [539]	validation_0-auc:0.983992	validation_1-auc:0.972837
# [540]	validation_0-auc:0.984025	validation_1-auc:0.972851
# [541]	validation_0-auc:0.98403	validation_1-auc:0.972868
# [542]	validation_0-auc:0.984046	validation_1-auc:0.972874
# [543]	validation_0-auc:0.984073	validation_1-auc:0.972913
# [544]	validation_0-auc:0.984088	validation_1-auc:0.972925
# [545]	validation_0-auc:0.984114	validation_1-auc:0.972982
# [546]	validation_0-auc:0.984172	validation_1-auc:0.973054
# [547]	validation_0-auc:0.984202	validation_1-auc:0.973057
# [548]	validation_0-auc:0.984219	validation_1-auc:0.973071
# [549]	validation_0-auc:0.984249	validation_1-auc:0.973121
# [550]	validation_0-auc:0.984289	validation_1-auc:0.973166
# [551]	validation_0-auc:0.98429	validation_1-auc:0.973168
# [552]	validation_0-auc:0.984305	validation_1-auc:0.973182
# [553]	validation_0-auc:0.984339	validation_1-auc:0.973233
# [554]	validation_0-auc:0.984371	validation_1-auc:0.973279
# [555]	validation_0-auc:0.984417	validation_1-auc:0.973324
# [556]	validation_0-auc:0.984447	validation_1-auc:0.973351
# [557]	validation_0-auc:0.984456	validation_1-auc:0.973358
# [558]	validation_0-auc:0.984494	validation_1-auc:0.973401
# [559]	validation_0-auc:0.98452	validation_1-auc:0.973414
# [560]	validation_0-auc:0.984553	validation_1-auc:0.973426
# [561]	validation_0-auc:0.984582	validation_1-auc:0.973475
# [562]	validation_0-auc:0.984624	validation_1-auc:0.973511
# [563]	validation_0-auc:0.984649	validation_1-auc:0.973548
# [564]	validation_0-auc:0.984678	validation_1-auc:0.973568
# [565]	validation_0-auc:0.984707	validation_1-auc:0.973604
# [566]	validation_0-auc:0.984753	validation_1-auc:0.973661
# [567]	validation_0-auc:0.984777	validation_1-auc:0.97369
# [568]	validation_0-auc:0.984808	validation_1-auc:0.973702
# [569]	validation_0-auc:0.984836	validation_1-auc:0.973743
# [570]	validation_0-auc:0.984859	validation_1-auc:0.973764
# [571]	validation_0-auc:0.984886	validation_1-auc:0.973783
# [572]	validation_0-auc:0.984914	validation_1-auc:0.973822
# [573]	validation_0-auc:0.984943	validation_1-auc:0.97383
# [574]	validation_0-auc:0.984952	validation_1-auc:0.973849
# [575]	validation_0-auc:0.984963	validation_1-auc:0.973864
# [576]	validation_0-auc:0.984997	validation_1-auc:0.973882
# [577]	validation_0-auc:0.985023	validation_1-auc:0.973909
# [578]	validation_0-auc:0.985057	validation_1-auc:0.973942
# [579]	validation_0-auc:0.985077	validation_1-auc:0.973967
# [580]	validation_0-auc:0.985101	validation_1-auc:0.973991
# [581]	validation_0-auc:0.98515	validation_1-auc:0.974034
# [582]	validation_0-auc:0.985166	validation_1-auc:0.974042
# [583]	validation_0-auc:0.985207	validation_1-auc:0.974097
# [584]	validation_0-auc:0.985249	validation_1-auc:0.974148
# [585]	validation_0-auc:0.985286	validation_1-auc:0.974208
# [586]	validation_0-auc:0.98533	validation_1-auc:0.97426
# [587]	validation_0-auc:0.985367	validation_1-auc:0.974311
# [588]	validation_0-auc:0.985411	validation_1-auc:0.974363
# [589]	validation_0-auc:0.985439	validation_1-auc:0.974376
# [590]	validation_0-auc:0.985451	validation_1-auc:0.974392
# [591]	validation_0-auc:0.985467	validation_1-auc:0.974408
# [592]	validation_0-auc:0.985487	validation_1-auc:0.974436
# [593]	validation_0-auc:0.985506	validation_1-auc:0.974449
# [594]	validation_0-auc:0.985553	validation_1-auc:0.974527
# [595]	validation_0-auc:0.985577	validation_1-auc:0.974548
# [596]	validation_0-auc:0.985625	validation_1-auc:0.974596
# [597]	validation_0-auc:0.985643	validation_1-auc:0.974627
# [598]	validation_0-auc:0.985639	validation_1-auc:0.97462
# [599]	validation_0-auc:0.985644	validation_1-auc:0.974623
# [600]	validation_0-auc:0.98568	validation_1-auc:0.974643
# [601]	validation_0-auc:0.985694	validation_1-auc:0.974658
# [602]	validation_0-auc:0.985712	validation_1-auc:0.974658
# [603]	validation_0-auc:0.985738	validation_1-auc:0.974675
# [604]	validation_0-auc:0.985764	validation_1-auc:0.974705
# [605]	validation_0-auc:0.985792	validation_1-auc:0.974744
# [606]	validation_0-auc:0.98581	validation_1-auc:0.974762
# [607]	validation_0-auc:0.985823	validation_1-auc:0.974773
# [608]	validation_0-auc:0.985852	validation_1-auc:0.974804
# [609]	validation_0-auc:0.985878	validation_1-auc:0.974831
# [610]	validation_0-auc:0.985927	validation_1-auc:0.974901
# [611]	validation_0-auc:0.985965	validation_1-auc:0.974947
# [612]	validation_0-auc:0.985978	validation_1-auc:0.974942
# [613]	validation_0-auc:0.986006	validation_1-auc:0.974976
# [614]	validation_0-auc:0.986027	validation_1-auc:0.975002
# [615]	validation_0-auc:0.986053	validation_1-auc:0.97503
# [616]	validation_0-auc:0.986068	validation_1-auc:0.975055
# [617]	validation_0-auc:0.986087	validation_1-auc:0.975061
# [618]	validation_0-auc:0.986107	validation_1-auc:0.975081
# [619]	validation_0-auc:0.986139	validation_1-auc:0.975119
# [620]	validation_0-auc:0.986174	validation_1-auc:0.975154
# [621]	validation_0-auc:0.986201	validation_1-auc:0.975187
# [622]	validation_0-auc:0.986243	validation_1-auc:0.975225
# [623]	validation_0-auc:0.986256	validation_1-auc:0.975233
# [624]	validation_0-auc:0.986281	validation_1-auc:0.97527
# [625]	validation_0-auc:0.986311	validation_1-auc:0.97528
# [626]	validation_0-auc:0.986342	validation_1-auc:0.975319
# [627]	validation_0-auc:0.986362	validation_1-auc:0.975327
# [628]	validation_0-auc:0.98638	validation_1-auc:0.975347
# [629]	validation_0-auc:0.986397	validation_1-auc:0.97536
# [630]	validation_0-auc:0.986429	validation_1-auc:0.975387
# [631]	validation_0-auc:0.986442	validation_1-auc:0.975395
# [632]	validation_0-auc:0.986469	validation_1-auc:0.975424
# [633]	validation_0-auc:0.986489	validation_1-auc:0.975433
# [634]	validation_0-auc:0.986502	validation_1-auc:0.975446
# [635]	validation_0-auc:0.986527	validation_1-auc:0.975469
# [636]	validation_0-auc:0.986554	validation_1-auc:0.975475
# [637]	validation_0-auc:0.986584	validation_1-auc:0.975505
# [638]	validation_0-auc:0.98659	validation_1-auc:0.975505
# [639]	validation_0-auc:0.986612	validation_1-auc:0.975526
# [640]	validation_0-auc:0.986637	validation_1-auc:0.97557
# [641]	validation_0-auc:0.986664	validation_1-auc:0.975603
# [642]	validation_0-auc:0.98669	validation_1-auc:0.975637
# [643]	validation_0-auc:0.986712	validation_1-auc:0.975648
# [644]	validation_0-auc:0.986729	validation_1-auc:0.975657
# [645]	validation_0-auc:0.986763	validation_1-auc:0.97568
# [646]	validation_0-auc:0.986787	validation_1-auc:0.9757
# [647]	validation_0-auc:0.98682	validation_1-auc:0.975733
# [648]	validation_0-auc:0.986831	validation_1-auc:0.975736
# [649]	validation_0-auc:0.986853	validation_1-auc:0.975767
# [650]	validation_0-auc:0.986864	validation_1-auc:0.975781
# [651]	validation_0-auc:0.986879	validation_1-auc:0.975794
# [652]	validation_0-auc:0.986912	validation_1-auc:0.97585
# [653]	validation_0-auc:0.986932	validation_1-auc:0.97585
# [654]	validation_0-auc:0.986955	validation_1-auc:0.975879
# [655]	validation_0-auc:0.986965	validation_1-auc:0.975896
# [656]	validation_0-auc:0.986976	validation_1-auc:0.975916
# [657]	validation_0-auc:0.986997	validation_1-auc:0.975933
# [658]	validation_0-auc:0.987022	validation_1-auc:0.975946
# [659]	validation_0-auc:0.987032	validation_1-auc:0.975976
# [660]	validation_0-auc:0.987055	validation_1-auc:0.976
# [661]	validation_0-auc:0.98706	validation_1-auc:0.975991
# [662]	validation_0-auc:0.98709	validation_1-auc:0.976037
# [663]	validation_0-auc:0.987117	validation_1-auc:0.976067
# [664]	validation_0-auc:0.987155	validation_1-auc:0.976088
# [665]	validation_0-auc:0.987186	validation_1-auc:0.976136
# [666]	validation_0-auc:0.987227	validation_1-auc:0.976171
# [667]	validation_0-auc:0.987246	validation_1-auc:0.976188
# [668]	validation_0-auc:0.987275	validation_1-auc:0.97621
# [669]	validation_0-auc:0.987301	validation_1-auc:0.976225
# [670]	validation_0-auc:0.987323	validation_1-auc:0.976251
# [671]	validation_0-auc:0.987353	validation_1-auc:0.976294
# [672]	validation_0-auc:0.987374	validation_1-auc:0.976316
# [673]	validation_0-auc:0.987393	validation_1-auc:0.976336
# [674]	validation_0-auc:0.987421	validation_1-auc:0.976364
# [675]	validation_0-auc:0.98743	validation_1-auc:0.97638
# [676]	validation_0-auc:0.987476	validation_1-auc:0.976446
# [677]	validation_0-auc:0.987506	validation_1-auc:0.976489
# [678]	validation_0-auc:0.987528	validation_1-auc:0.976516
# [679]	validation_0-auc:0.987563	validation_1-auc:0.976561
# [680]	validation_0-auc:0.987605	validation_1-auc:0.976591
# [681]	validation_0-auc:0.987626	validation_1-auc:0.976615
# [682]	validation_0-auc:0.987665	validation_1-auc:0.976663
# [683]	validation_0-auc:0.98768	validation_1-auc:0.976675
# [684]	validation_0-auc:0.987683	validation_1-auc:0.976688
# [685]	validation_0-auc:0.987705	validation_1-auc:0.976713
# [686]	validation_0-auc:0.987718	validation_1-auc:0.976757
# [687]	validation_0-auc:0.987734	validation_1-auc:0.976782
# [688]	validation_0-auc:0.987756	validation_1-auc:0.976802
# [689]	validation_0-auc:0.987764	validation_1-auc:0.976829
# [690]	validation_0-auc:0.987778	validation_1-auc:0.976851
# [691]	validation_0-auc:0.987798	validation_1-auc:0.976875
# [692]	validation_0-auc:0.987814	validation_1-auc:0.976894
# [693]	validation_0-auc:0.987829	validation_1-auc:0.9769
# [694]	validation_0-auc:0.987859	validation_1-auc:0.976941
# [695]	validation_0-auc:0.987866	validation_1-auc:0.976953
# [696]	validation_0-auc:0.987883	validation_1-auc:0.976962
# [697]	validation_0-auc:0.987921	validation_1-auc:0.977002
# [698]	validation_0-auc:0.987929	validation_1-auc:0.977004
# [699]	validation_0-auc:0.987947	validation_1-auc:0.977023
# [700]	validation_0-auc:0.987974	validation_1-auc:0.97706
# [701]	validation_0-auc:0.987999	validation_1-auc:0.977081
# [702]	validation_0-auc:0.988023	validation_1-auc:0.977112
# [703]	validation_0-auc:0.988055	validation_1-auc:0.97715
# [704]	validation_0-auc:0.98807	validation_1-auc:0.977152
# [705]	validation_0-auc:0.988091	validation_1-auc:0.977188
# [706]	validation_0-auc:0.988104	validation_1-auc:0.977209
# [707]	validation_0-auc:0.988119	validation_1-auc:0.977232
# [708]	validation_0-auc:0.988129	validation_1-auc:0.977236
# [709]	validation_0-auc:0.988155	validation_1-auc:0.977251
# [710]	validation_0-auc:0.988182	validation_1-auc:0.977288
# [711]	validation_0-auc:0.988202	validation_1-auc:0.97731
# [712]	validation_0-auc:0.98821	validation_1-auc:0.977316
# [713]	validation_0-auc:0.988221	validation_1-auc:0.977328
# [714]	validation_0-auc:0.988241	validation_1-auc:0.977337
# [715]	validation_0-auc:0.988275	validation_1-auc:0.977382
# [716]	validation_0-auc:0.988296	validation_1-auc:0.977403
# [717]	validation_0-auc:0.988314	validation_1-auc:0.977414
# [718]	validation_0-auc:0.988338	validation_1-auc:0.977434
# [719]	validation_0-auc:0.988359	validation_1-auc:0.977451
# [720]	validation_0-auc:0.988399	validation_1-auc:0.977486
# [721]	validation_0-auc:0.988403	validation_1-auc:0.977493
# [722]	validation_0-auc:0.988436	validation_1-auc:0.977524
# [723]	validation_0-auc:0.98846	validation_1-auc:0.977557
# [724]	validation_0-auc:0.988497	validation_1-auc:0.977597
# [725]	validation_0-auc:0.988517	validation_1-auc:0.977622
# [726]	validation_0-auc:0.988539	validation_1-auc:0.977648
# [727]	validation_0-auc:0.988557	validation_1-auc:0.977684
# [728]	validation_0-auc:0.988593	validation_1-auc:0.977719
# [729]	validation_0-auc:0.988609	validation_1-auc:0.977728
# [730]	validation_0-auc:0.988622	validation_1-auc:0.977721
# [731]	validation_0-auc:0.988632	validation_1-auc:0.977724
# [732]	validation_0-auc:0.988647	validation_1-auc:0.977737
# [733]	validation_0-auc:0.988657	validation_1-auc:0.977749
# [734]	validation_0-auc:0.988684	validation_1-auc:0.977777
# [735]	validation_0-auc:0.988708	validation_1-auc:0.977808
# [736]	validation_0-auc:0.988733	validation_1-auc:0.977826
# [737]	validation_0-auc:0.988766	validation_1-auc:0.977872
# [738]	validation_0-auc:0.98879	validation_1-auc:0.977896
# [739]	validation_0-auc:0.988815	validation_1-auc:0.977912
# [740]	validation_0-auc:0.988842	validation_1-auc:0.977934
# [741]	validation_0-auc:0.988851	validation_1-auc:0.977943
# [742]	validation_0-auc:0.988869	validation_1-auc:0.977947
# [743]	validation_0-auc:0.98889	validation_1-auc:0.977972
# [744]	validation_0-auc:0.988892	validation_1-auc:0.977988
# [745]	validation_0-auc:0.988911	validation_1-auc:0.978018
# [746]	validation_0-auc:0.988936	validation_1-auc:0.978043
# [747]	validation_0-auc:0.988951	validation_1-auc:0.978066
# [748]	validation_0-auc:0.988963	validation_1-auc:0.978085
# [749]	validation_0-auc:0.988986	validation_1-auc:0.978115
# [750]	validation_0-auc:0.989001	validation_1-auc:0.978139
# [751]	validation_0-auc:0.989025	validation_1-auc:0.978165
# [752]	validation_0-auc:0.989032	validation_1-auc:0.97817
# [753]	validation_0-auc:0.989046	validation_1-auc:0.978176
# [754]	validation_0-auc:0.989072	validation_1-auc:0.978202
# [755]	validation_0-auc:0.989096	validation_1-auc:0.978231
# [756]	validation_0-auc:0.989105	validation_1-auc:0.978244
# [757]	validation_0-auc:0.989118	validation_1-auc:0.978241
# [758]	validation_0-auc:0.989135	validation_1-auc:0.978254
# [759]	validation_0-auc:0.989148	validation_1-auc:0.978266
# [760]	validation_0-auc:0.989156	validation_1-auc:0.978269
# [761]	validation_0-auc:0.989178	validation_1-auc:0.978285
# [762]	validation_0-auc:0.989195	validation_1-auc:0.978297
# [763]	validation_0-auc:0.989218	validation_1-auc:0.978303
# [764]	validation_0-auc:0.989246	validation_1-auc:0.978333
# [765]	validation_0-auc:0.989259	validation_1-auc:0.978343
# [766]	validation_0-auc:0.98928	validation_1-auc:0.978368
# [767]	validation_0-auc:0.989302	validation_1-auc:0.978395
# [768]	validation_0-auc:0.989319	validation_1-auc:0.978405
# [769]	validation_0-auc:0.989339	validation_1-auc:0.978422
# [770]	validation_0-auc:0.989365	validation_1-auc:0.978446
# [771]	validation_0-auc:0.989387	validation_1-auc:0.978458
# [772]	validation_0-auc:0.989408	validation_1-auc:0.978491
# [773]	validation_0-auc:0.989425	validation_1-auc:0.978499
# [774]	validation_0-auc:0.989437	validation_1-auc:0.978529
# [775]	validation_0-auc:0.989473	validation_1-auc:0.978562
# [776]	validation_0-auc:0.989483	validation_1-auc:0.978589
# [777]	validation_0-auc:0.989493	validation_1-auc:0.978596
# [778]	validation_0-auc:0.989504	validation_1-auc:0.978612
# [779]	validation_0-auc:0.989519	validation_1-auc:0.978648
# [780]	validation_0-auc:0.989535	validation_1-auc:0.978659
# [781]	validation_0-auc:0.989546	validation_1-auc:0.978677
# [782]	validation_0-auc:0.989552	validation_1-auc:0.978675
# [783]	validation_0-auc:0.989574	validation_1-auc:0.978688
# [784]	validation_0-auc:0.989581	validation_1-auc:0.978698
# [785]	validation_0-auc:0.989587	validation_1-auc:0.978702
# [786]	validation_0-auc:0.989604	validation_1-auc:0.978714
# [787]	validation_0-auc:0.989614	validation_1-auc:0.978717
# [788]	validation_0-auc:0.989637	validation_1-auc:0.978749
# [789]	validation_0-auc:0.989653	validation_1-auc:0.978765
# [790]	validation_0-auc:0.989672	validation_1-auc:0.978764
# [791]	validation_0-auc:0.989692	validation_1-auc:0.978783
# [792]	validation_0-auc:0.989699	validation_1-auc:0.978773
# [793]	validation_0-auc:0.989717	validation_1-auc:0.978798
# [794]	validation_0-auc:0.989744	validation_1-auc:0.978827
# [795]	validation_0-auc:0.989761	validation_1-auc:0.978835
# [796]	validation_0-auc:0.989779	validation_1-auc:0.978846
# [797]	validation_0-auc:0.989798	validation_1-auc:0.978865
# [798]	validation_0-auc:0.989821	validation_1-auc:0.978885
# [799]	validation_0-auc:0.989835	validation_1-auc:0.978909
# [800]	validation_0-auc:0.989835	validation_1-auc:0.978908
# [801]	validation_0-auc:0.989859	validation_1-auc:0.978938
# [802]	validation_0-auc:0.989873	validation_1-auc:0.978944
# [803]	validation_0-auc:0.989889	validation_1-auc:0.97898
# [804]	validation_0-auc:0.98991	validation_1-auc:0.978997
# [805]	validation_0-auc:0.989919	validation_1-auc:0.979008
# [806]	validation_0-auc:0.989944	validation_1-auc:0.979038
# [807]	validation_0-auc:0.989973	validation_1-auc:0.979067
# [808]	validation_0-auc:0.989998	validation_1-auc:0.979098
# [809]	validation_0-auc:0.990009	validation_1-auc:0.979103
# [810]	validation_0-auc:0.990029	validation_1-auc:0.979143
# [811]	validation_0-auc:0.990054	validation_1-auc:0.979174
# [812]	validation_0-auc:0.990063	validation_1-auc:0.979174
# [813]	validation_0-auc:0.990069	validation_1-auc:0.97917
# [814]	validation_0-auc:0.990091	validation_1-auc:0.979195
# [815]	validation_0-auc:0.990108	validation_1-auc:0.979222
# [816]	validation_0-auc:0.990129	validation_1-auc:0.979246
# [817]	validation_0-auc:0.990155	validation_1-auc:0.979261
# [818]	validation_0-auc:0.990159	validation_1-auc:0.979255
# [819]	validation_0-auc:0.990177	validation_1-auc:0.979274
# [820]	validation_0-auc:0.990194	validation_1-auc:0.979293
# [821]	validation_0-auc:0.990208	validation_1-auc:0.979302
# [822]	validation_0-auc:0.99022	validation_1-auc:0.979316
# ...
# [3737]	validation_0-auc:0.999863	validation_1-auc:0.987515
# [3738]	validation_0-auc:0.999863	validation_1-auc:0.987515
# [3739]	validation_0-auc:0.999863	validation_1-auc:0.987515
# [3740]	validation_0-auc:0.999864	validation_1-auc:0.987516
# [3741]	validation_0-auc:0.999864	validation_1-auc:0.98752
# [3742]	validation_0-auc:0.999864	validation_1-auc:0.987518
# [3743]	validation_0-auc:0.999865	validation_1-auc:0.987514
# [3744]	validation_0-auc:0.999866	validation_1-auc:0.987515
# [3745]	validation_0-auc:0.999866	validation_1-auc:0.987516
# [3746]	validation_0-auc:0.999866	validation_1-auc:0.987515
# [3747]	validation_0-auc:0.999866	validation_1-auc:0.987518
# [3748]	validation_0-auc:0.999867	validation_1-auc:0.987519
# [3749]	validation_0-auc:0.999867	validation_1-auc:0.987517
# [3750]	validation_0-auc:0.999868	validation_1-auc:0.987518
# [3751]	validation_0-auc:0.999869	validation_1-auc:0.987518
# [3752]	validation_0-auc:0.999869	validation_1-auc:0.987515
# [3753]	validation_0-auc:0.99987	validation_1-auc:0.987516
# [3754]	validation_0-auc:0.99987	validation_1-auc:0.987518
# [3755]	validation_0-auc:0.99987	validation_1-auc:0.987516
# [3756]	validation_0-auc:0.999871	validation_1-auc:0.987514
# [3757]	validation_0-auc:0.999871	validation_1-auc:0.987513
# [3758]	validation_0-auc:0.999871	validation_1-auc:0.987514
# [3759]	validation_0-auc:0.999872	validation_1-auc:0.987511
# [3760]	validation_0-auc:0.999873	validation_1-auc:0.987513
# [3761]	validation_0-auc:0.999874	validation_1-auc:0.987512
# [3762]	validation_0-auc:0.999874	validation_1-auc:0.987513
# [3763]	validation_0-auc:0.999874	validation_1-auc:0.98751
# [3764]	validation_0-auc:0.999875	validation_1-auc:0.987515
# [3765]	validation_0-auc:0.999875	validation_1-auc:0.987514
# [3766]	validation_0-auc:0.999875	validation_1-auc:0.987515
# [3767]	validation_0-auc:0.999876	validation_1-auc:0.987515
# [3768]	validation_0-auc:0.999876	validation_1-auc:0.987514
# [3769]	validation_0-auc:0.999876	validation_1-auc:0.987512
# [3770]	validation_0-auc:0.999876	validation_1-auc:0.987514
# [3771]	validation_0-auc:0.999877	validation_1-auc:0.987515
# [3772]	validation_0-auc:0.999877	validation_1-auc:0.987514
# [3773]	validation_0-auc:0.999877	validation_1-auc:0.987515
# [3774]	validation_0-auc:0.999878	validation_1-auc:0.987514
# [3775]	validation_0-auc:0.999878	validation_1-auc:0.987512
# [3776]	validation_0-auc:0.999878	validation_1-auc:0.987515
# [3777]	validation_0-auc:0.999879	validation_1-auc:0.987515
# [3778]	validation_0-auc:0.999879	validation_1-auc:0.987513
# [3779]	validation_0-auc:0.999879	validation_1-auc:0.987513
# [3780]	validation_0-auc:0.999879	validation_1-auc:0.987515
# [3781]	validation_0-auc:0.99988	validation_1-auc:0.987516
# [3782]	validation_0-auc:0.99988	validation_1-auc:0.987518
# [3783]	validation_0-auc:0.99988	validation_1-auc:0.987515
# [3784]	validation_0-auc:0.99988	validation_1-auc:0.987514
# [3785]	validation_0-auc:0.999881	validation_1-auc:0.987516
# [3786]	validation_0-auc:0.999881	validation_1-auc:0.987516
# [3787]	validation_0-auc:0.999881	validation_1-auc:0.987518
# [3788]	validation_0-auc:0.999882	validation_1-auc:0.987518
# [3789]	validation_0-auc:0.999882	validation_1-auc:0.98752
# [3790]	validation_0-auc:0.999882	validation_1-auc:0.987517
# [3791]	validation_0-auc:0.999882	validation_1-auc:0.987518
# [3792]	validation_0-auc:0.999882	validation_1-auc:0.987517
# [3793]	validation_0-auc:0.999883	validation_1-auc:0.987519
# [3794]	validation_0-auc:0.999883	validation_1-auc:0.987517
# [3795]	validation_0-auc:0.999884	validation_1-auc:0.98752
# [3796]	validation_0-auc:0.999884	validation_1-auc:0.987521
# [3797]	validation_0-auc:0.999884	validation_1-auc:0.987523
# [3798]	validation_0-auc:0.999884	validation_1-auc:0.987525
# [3799]	validation_0-auc:0.999885	validation_1-auc:0.987524
# [3800]	validation_0-auc:0.999885	validation_1-auc:0.987524
# [3801]	validation_0-auc:0.999885	validation_1-auc:0.987522
# [3802]	validation_0-auc:0.999885	validation_1-auc:0.987522
# [3803]	validation_0-auc:0.999885	validation_1-auc:0.987523
# [3804]	validation_0-auc:0.999886	validation_1-auc:0.987525
# [3805]	validation_0-auc:0.999886	validation_1-auc:0.987528
# [3806]	validation_0-auc:0.999886	validation_1-auc:0.98753
# [3807]	validation_0-auc:0.999886	validation_1-auc:0.987529
# [3808]	validation_0-auc:0.999886	validation_1-auc:0.987529
# [3809]	validation_0-auc:0.999886	validation_1-auc:0.98753
# [3810]	validation_0-auc:0.999886	validation_1-auc:0.987531
# [3811]	validation_0-auc:0.999886	validation_1-auc:0.987533
# [3812]	validation_0-auc:0.999887	validation_1-auc:0.987534
# [3813]	validation_0-auc:0.999887	validation_1-auc:0.987534
# [3814]	validation_0-auc:0.999888	validation_1-auc:0.987533
# [3815]	validation_0-auc:0.999888	validation_1-auc:0.987537
# [3816]	validation_0-auc:0.999888	validation_1-auc:0.987537
# [3817]	validation_0-auc:0.999888	validation_1-auc:0.987537
# [3818]	validation_0-auc:0.999888	validation_1-auc:0.987538
# [3819]	validation_0-auc:0.999888	validation_1-auc:0.987539
# [3820]	validation_0-auc:0.999889	validation_1-auc:0.987536
# [3821]	validation_0-auc:0.999889	validation_1-auc:0.987538
# [3822]	validation_0-auc:0.99989	validation_1-auc:0.987536
# [3823]	validation_0-auc:0.99989	validation_1-auc:0.987535
# [3824]	validation_0-auc:0.999891	validation_1-auc:0.987533
# [3825]	validation_0-auc:0.999891	validation_1-auc:0.987535
# [3826]	validation_0-auc:0.999891	validation_1-auc:0.987537
# [3827]	validation_0-auc:0.999891	validation_1-auc:0.987535
# [3828]	validation_0-auc:0.999892	validation_1-auc:0.987538
# [3829]	validation_0-auc:0.999892	validation_1-auc:0.98754
# [3830]	validation_0-auc:0.999892	validation_1-auc:0.987539
# [3831]	validation_0-auc:0.999892	validation_1-auc:0.987541
# [3832]	validation_0-auc:0.999892	validation_1-auc:0.98754
# [3833]	validation_0-auc:0.999892	validation_1-auc:0.987541
# [3834]	validation_0-auc:0.999892	validation_1-auc:0.987541
# [3835]	validation_0-auc:0.999893	validation_1-auc:0.987541
# [3836]	validation_0-auc:0.999893	validation_1-auc:0.987545
# [3837]	validation_0-auc:0.999893	validation_1-auc:0.987549
# [3838]	validation_0-auc:0.999893	validation_1-auc:0.987548
# [3839]	validation_0-auc:0.999894	validation_1-auc:0.987552
# [3840]	validation_0-auc:0.999894	validation_1-auc:0.987551
# [3841]	validation_0-auc:0.999894	validation_1-auc:0.98755
# [3842]	validation_0-auc:0.999894	validation_1-auc:0.987554
# [3843]	validation_0-auc:0.999895	validation_1-auc:0.987553
# [3844]	validation_0-auc:0.999895	validation_1-auc:0.987553
# [3845]	validation_0-auc:0.999895	validation_1-auc:0.987552
# [3846]	validation_0-auc:0.999895	validation_1-auc:0.987553
# [3847]	validation_0-auc:0.999896	validation_1-auc:0.987555
# [3848]	validation_0-auc:0.999896	validation_1-auc:0.987553
# [3849]	validation_0-auc:0.999896	validation_1-auc:0.987554
# [3850]	validation_0-auc:0.999897	validation_1-auc:0.987554
# [3851]	validation_0-auc:0.999897	validation_1-auc:0.987558
# [3852]	validation_0-auc:0.999897	validation_1-auc:0.987558
# [3853]	validation_0-auc:0.999897	validation_1-auc:0.987556
# [3854]	validation_0-auc:0.999898	validation_1-auc:0.987558
# [3855]	validation_0-auc:0.999898	validation_1-auc:0.987554
# [3856]	validation_0-auc:0.999898	validation_1-auc:0.987554
# [3857]	validation_0-auc:0.999898	validation_1-auc:0.987554
# [3858]	validation_0-auc:0.999899	validation_1-auc:0.987553
# [3859]	validation_0-auc:0.999899	validation_1-auc:0.987555
# [3860]	validation_0-auc:0.999899	validation_1-auc:0.987555
# [3861]	validation_0-auc:0.999899	validation_1-auc:0.987553
# [3862]	validation_0-auc:0.999899	validation_1-auc:0.987552
# [3863]	validation_0-auc:0.9999	validation_1-auc:0.987554
# [3864]	validation_0-auc:0.9999	validation_1-auc:0.987554
# [3865]	validation_0-auc:0.9999	validation_1-auc:0.987557
# [3866]	validation_0-auc:0.9999	validation_1-auc:0.98756
# [3867]	validation_0-auc:0.9999	validation_1-auc:0.98756
# [3868]	validation_0-auc:0.999901	validation_1-auc:0.987565
# [3869]	validation_0-auc:0.999901	validation_1-auc:0.987567
# [3870]	validation_0-auc:0.999902	validation_1-auc:0.987569
# [3871]	validation_0-auc:0.999902	validation_1-auc:0.987573
# [3872]	validation_0-auc:0.999903	validation_1-auc:0.987573
# [3873]	validation_0-auc:0.999903	validation_1-auc:0.987574
# [3874]	validation_0-auc:0.999903	validation_1-auc:0.987574
# [3875]	validation_0-auc:0.999903	validation_1-auc:0.987572
# [3876]	validation_0-auc:0.999903	validation_1-auc:0.987574
# [3877]	validation_0-auc:0.999903	validation_1-auc:0.987572
# [3878]	validation_0-auc:0.999903	validation_1-auc:0.987571
# [3879]	validation_0-auc:0.999904	validation_1-auc:0.987572
# [3880]	validation_0-auc:0.999904	validation_1-auc:0.987569
# [3881]	validation_0-auc:0.999904	validation_1-auc:0.987571
# [3882]	validation_0-auc:0.999904	validation_1-auc:0.98757
# [3883]	validation_0-auc:0.999904	validation_1-auc:0.987572
# [3884]	validation_0-auc:0.999904	validation_1-auc:0.987574
# [3885]	validation_0-auc:0.999904	validation_1-auc:0.987576
# [3886]	validation_0-auc:0.999904	validation_1-auc:0.987576
# [3887]	validation_0-auc:0.999904	validation_1-auc:0.987576
# [3888]	validation_0-auc:0.999905	validation_1-auc:0.987579
# [3889]	validation_0-auc:0.999905	validation_1-auc:0.987578
# [3890]	validation_0-auc:0.999905	validation_1-auc:0.987574
# [3891]	validation_0-auc:0.999906	validation_1-auc:0.987576
# [3892]	validation_0-auc:0.999906	validation_1-auc:0.987579
# [3893]	validation_0-auc:0.999907	validation_1-auc:0.987578
# [3894]	validation_0-auc:0.999907	validation_1-auc:0.987577
# [3895]	validation_0-auc:0.999907	validation_1-auc:0.987575
# [3896]	validation_0-auc:0.999908	validation_1-auc:0.987577
# [3897]	validation_0-auc:0.999907	validation_1-auc:0.987577
# [3898]	validation_0-auc:0.999908	validation_1-auc:0.987578
# [3899]	validation_0-auc:0.999908	validation_1-auc:0.987576
# [3900]	validation_0-auc:0.999908	validation_1-auc:0.987574
# [3901]	validation_0-auc:0.999908	validation_1-auc:0.987574
# [3902]	validation_0-auc:0.999909	validation_1-auc:0.987575
# [3903]	validation_0-auc:0.999909	validation_1-auc:0.987574
# [3904]	validation_0-auc:0.999909	validation_1-auc:0.987573
# [3905]	validation_0-auc:0.99991	validation_1-auc:0.987576
# [3906]	validation_0-auc:0.99991	validation_1-auc:0.987577
# [3907]	validation_0-auc:0.99991	validation_1-auc:0.987578
# [3908]	validation_0-auc:0.999911	validation_1-auc:0.987577
# [3909]	validation_0-auc:0.999911	validation_1-auc:0.987577
# [3910]	validation_0-auc:0.999911	validation_1-auc:0.987577
# [3911]	validation_0-auc:0.999911	validation_1-auc:0.987577
# [3912]	validation_0-auc:0.999912	validation_1-auc:0.987574
# [3913]	validation_0-auc:0.999912	validation_1-auc:0.987577
# [3914]	validation_0-auc:0.999912	validation_1-auc:0.987579
# [3915]	validation_0-auc:0.999912	validation_1-auc:0.987579
# [3916]	validation_0-auc:0.999913	validation_1-auc:0.987577
# [3917]	validation_0-auc:0.999913	validation_1-auc:0.987578
# [3918]	validation_0-auc:0.999913	validation_1-auc:0.987579
# [3919]	validation_0-auc:0.999913	validation_1-auc:0.987582
# [3920]	validation_0-auc:0.999913	validation_1-auc:0.987582
# [3921]	validation_0-auc:0.999913	validation_1-auc:0.987583
# [3922]	validation_0-auc:0.999913	validation_1-auc:0.987585
# [3923]	validation_0-auc:0.999914	validation_1-auc:0.987585
# [3924]	validation_0-auc:0.999914	validation_1-auc:0.987585
# [3925]	validation_0-auc:0.999914	validation_1-auc:0.987582
# [3926]	validation_0-auc:0.999915	validation_1-auc:0.987582
# [3927]	validation_0-auc:0.999915	validation_1-auc:0.987585
# [3928]	validation_0-auc:0.999915	validation_1-auc:0.987584
# [3929]	validation_0-auc:0.999915	validation_1-auc:0.987585
# [3930]	validation_0-auc:0.999915	validation_1-auc:0.987586
# [3931]	validation_0-auc:0.999915	validation_1-auc:0.987587
# [3932]	validation_0-auc:0.999916	validation_1-auc:0.987587
# [3933]	validation_0-auc:0.999916	validation_1-auc:0.987587
# [3934]	validation_0-auc:0.999916	validation_1-auc:0.987586
# [3935]	validation_0-auc:0.999916	validation_1-auc:0.987587
# [3936]	validation_0-auc:0.999916	validation_1-auc:0.987588
# [3937]	validation_0-auc:0.999916	validation_1-auc:0.987588
# [3938]	validation_0-auc:0.999917	validation_1-auc:0.987588
# [3939]	validation_0-auc:0.999917	validation_1-auc:0.987588
# [3940]	validation_0-auc:0.999917	validation_1-auc:0.987585
# [3941]	validation_0-auc:0.999918	validation_1-auc:0.987586
# [3942]	validation_0-auc:0.999918	validation_1-auc:0.987586
# [3943]	validation_0-auc:0.999918	validation_1-auc:0.987588
# [3944]	validation_0-auc:0.999918	validation_1-auc:0.987588
# [3945]	validation_0-auc:0.999918	validation_1-auc:0.987587
# [3946]	validation_0-auc:0.999918	validation_1-auc:0.987586
# [3947]	validation_0-auc:0.999918	validation_1-auc:0.987585
# [3948]	validation_0-auc:0.999919	validation_1-auc:0.987585
# [3949]	validation_0-auc:0.999919	validation_1-auc:0.987586
# [3950]	validation_0-auc:0.999919	validation_1-auc:0.987588
# [3951]	validation_0-auc:0.999919	validation_1-auc:0.987586
# [3952]	validation_0-auc:0.999919	validation_1-auc:0.987585
# [3953]	validation_0-auc:0.999919	validation_1-auc:0.987584
# [3954]	validation_0-auc:0.99992	validation_1-auc:0.987585
# [3955]	validation_0-auc:0.99992	validation_1-auc:0.987586
# [3956]	validation_0-auc:0.99992	validation_1-auc:0.987587
# [3957]	validation_0-auc:0.99992	validation_1-auc:0.987586
# [3958]	validation_0-auc:0.99992	validation_1-auc:0.987587
# [3959]	validation_0-auc:0.99992	validation_1-auc:0.987587
# [3960]	validation_0-auc:0.999921	validation_1-auc:0.987587
# [3961]	validation_0-auc:0.999921	validation_1-auc:0.987589
# [3962]	validation_0-auc:0.999921	validation_1-auc:0.987587
# [3963]	validation_0-auc:0.999922	validation_1-auc:0.98759
# [3964]	validation_0-auc:0.999922	validation_1-auc:0.987585
# [3965]	validation_0-auc:0.999922	validation_1-auc:0.987588
# [3966]	validation_0-auc:0.999922	validation_1-auc:0.987589
# [3967]	validation_0-auc:0.999922	validation_1-auc:0.987591
# [3968]	validation_0-auc:0.999922	validation_1-auc:0.987592
# [3969]	validation_0-auc:0.999922	validation_1-auc:0.987592
# [3970]	validation_0-auc:0.999923	validation_1-auc:0.987592
# [3971]	validation_0-auc:0.999923	validation_1-auc:0.987592
# [3972]	validation_0-auc:0.999924	validation_1-auc:0.987593
# [3973]	validation_0-auc:0.999924	validation_1-auc:0.987595
# [3974]	validation_0-auc:0.999924	validation_1-auc:0.987596
# [3975]	validation_0-auc:0.999924	validation_1-auc:0.987592
# [3976]	validation_0-auc:0.999924	validation_1-auc:0.98759
# [3977]	validation_0-auc:0.999925	validation_1-auc:0.98759
# [3978]	validation_0-auc:0.999925	validation_1-auc:0.987591
# [3979]	validation_0-auc:0.999925	validation_1-auc:0.987592
# [3980]	validation_0-auc:0.999925	validation_1-auc:0.987593
# [3981]	validation_0-auc:0.999925	validation_1-auc:0.987595
# [3982]	validation_0-auc:0.999926	validation_1-auc:0.987595
# [3983]	validation_0-auc:0.999926	validation_1-auc:0.987597
# [3984]	validation_0-auc:0.999926	validation_1-auc:0.987599
# [3985]	validation_0-auc:0.999926	validation_1-auc:0.987598
# [3986]	validation_0-auc:0.999927	validation_1-auc:0.987596
# [3987]	validation_0-auc:0.999927	validation_1-auc:0.987597
# [3988]	validation_0-auc:0.999927	validation_1-auc:0.987595
# [3989]	validation_0-auc:0.999927	validation_1-auc:0.987598
# [3990]	validation_0-auc:0.999928	validation_1-auc:0.987597
# [3991]	validation_0-auc:0.999928	validation_1-auc:0.987601
# [3992]	validation_0-auc:0.999928	validation_1-auc:0.987601
# [3993]	validation_0-auc:0.999928	validation_1-auc:0.9876
# [3994]	validation_0-auc:0.999928	validation_1-auc:0.987598
# [3995]	validation_0-auc:0.999928	validation_1-auc:0.987596
# [3996]	validation_0-auc:0.999929	validation_1-auc:0.987597
# [3997]	validation_0-auc:0.999929	validation_1-auc:0.987598
# [3998]	validation_0-auc:0.999929	validation_1-auc:0.987597
# [3999]	validation_0-auc:0.999929	validation_1-auc:0.987596
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.8, gamma=0,
#        learning_rate=0.01, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=4000, n_jobs=-1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27,
#        silent=False, subsample=0.8, tree_method='gpu_hist',
#        verbose_eval=10, verbosity=1)

# %% [markdown]
# # Evaluate model
# Check to see how the model performs in the training vs testing. We can also review to see which of the features are the most influencial to the model's performance. You can see that the training accuracy was over 99% and the accuracy on the testing set was 97.45%

# %%
model.score(X_test, y_test)
# Out:
# 0.9767

# %% [markdown]
# # We can sort the values to see which are the most important

# %%
pd.DataFrame(model.feature_importances_, index=columns).sort_values(0, ascending=False).head()
# Out:
#             0
# x75  0.034177
# x97  0.031398
# x37  0.028549
# x41  0.025194
# x58  0.025010
